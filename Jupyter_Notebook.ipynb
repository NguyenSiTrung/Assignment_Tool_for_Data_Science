# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Nguyen Si Trung**
# Current occupation: Mobile Development

# %% [markdown]
# *I am interested in data science because it is an area with great potential for growth in the future, I can develop myself and realize many of my plans when I have knowledge about it.*

# %% [markdown]
# ### Calculate 1 + 1

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# ~~An example of strikethrough text~~
# ````
# ```
# Look! You can see my highligh.
# ```
# ````
# <hr *** />
